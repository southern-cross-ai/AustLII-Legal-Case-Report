# %%
import re
import os
import json

def extract_citphrases(xml_content):
    pattern = r'<citphrase\s+(.*?)>(.*?)</citphrase>'
    matches = re.findall(pattern, xml_content, re.DOTALL)
    
    citphrases = []
    for attrs, text in matches:
        citphrase = {'text': text.strip()}
        # Corrected and improved regex for attribute extraction
        attr_matches = re.findall(r'(\w+)\s*=\s*["\']?([^"\'>\s]+)["\']?', attrs)
        for key, value in attr_matches:
            citphrase[key] = value
        citphrases.append(citphrase)
    
    return citphrases

def read_file_with_fallback_encoding(file_path):
    encodings = ['utf-8', 'latin-1', 'iso-8859-1']
    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as file:
                return file.read()
        except UnicodeDecodeError:
            continue
    return None

def process_xml_files(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    total_files = 0
    cleaned_files = 0
    error_files = 0

    for filename in os.listdir(input_folder):
        if filename.endswith('.xml'):
            total_files += 1
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename[:-4] + '.json')
            
            try:
                xml_content = read_file_with_fallback_encoding(input_path)
                if xml_content is None:
                    print(f"Failed to read file with supported encodings: {filename}")
                    error_files += 1
                    continue
                
                citphrases = extract_citphrases(xml_content)
                
                if citphrases:
                    with open(output_path, 'w', encoding='utf-8') as file:
                        json.dump(citphrases, file, indent=2, ensure_ascii=False)
                    print(f"Processed and saved as JSON: {filename}")
                    cleaned_files += 1
                else:
                    print(f"No citphrases found in: {filename}")
                    error_files += 1
            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")
                error_files += 1

    print(f"\nProcessing complete. Summary:")
    print(f"Total files processed: {total_files}")
    print(f"Successfully cleaned files: {cleaned_files}")
    print(f"Files with errors: {error_files}")

def main():
    current_dir = os.getcwd()
    parent_dir = os.path.dirname(os.path.dirname(current_dir))
    input_folder = os.path.join(parent_dir, "AustLII-Legal-Case-Report", "dataset", "corpus", "citations_summ")
    output_folder = os.path.join(parent_dir, "AustLII-Legal-Case-Report", "dataset", "cleaned_dataset", "citations_summ")

    process_xml_files(input_folder, output_folder)

if __name__ == "__main__":
    main()
# Out:
# Processed and saved as JSON: 06_1.xml
# No citphrases found in: 06_100.xml
# Processed and saved as JSON: 06_1001.xml
# Processed and saved as JSON: 06_1004.xml
# Processed and saved as JSON: 06_1005.xml
# No citphrases found in: 06_1006.xml
# No citphrases found in: 06_1015.xml
# Processed and saved as JSON: 06_1017.xml
# Processed and saved as JSON: 06_1018.xml
# Processed and saved as JSON: 06_102.xml
# Processed and saved as JSON: 06_1021.xml
# Processed and saved as JSON: 06_1022.xml
# Processed and saved as JSON: 06_1023.xml
# Processed and saved as JSON: 06_1026.xml
# Processed and saved as JSON: 06_1027.xml
# Processed and saved as JSON: 06_1028.xml
# Processed and saved as JSON: 06_1029.xml
# No citphrases found in: 06_1032.xml
# Processed and saved as JSON: 06_1033.xml
# Processed and saved as JSON: 06_1041.xml
# Processed and saved as JSON: 06_1042.xml
# Processed and saved as JSON: 06_1043.xml
# Processed and saved as JSON: 06_1044.xml
# Processed and saved as JSON: 06_1045.xml
# Processed and saved as JSON: 06_1046.xml
# Processed and saved as JSON: 06_1048.xml
# Processed and saved as JSON: 06_1049.xml
# Processed and saved as JSON: 06_105.xml
# Processed and saved as JSON: 06_1050.xml
# No citphrases found in: 06_1051.xml
# Processed and saved as JSON: 06_1054.xml
# No citphrases found in: 06_1056.xml
# Processed and saved as JSON: 06_106.xml
# Processed and saved as JSON: 06_1066.xml
# Processed and saved as JSON: 06_1069.xml
# Processed and saved as JSON: 06_107.xml
# Processed and saved as JSON: 06_1070.xml
# Processed and saved as JSON: 06_1071.xml
# Processed and saved as JSON: 06_1072.xml
# Processed and saved as JSON: 06_1073.xml
# Processed and saved as JSON: 06_1074.xml
# Processed and saved as JSON: 06_1075.xml
# Processed and saved as JSON: 06_1077.xml
# Processed and saved as JSON: 06_1078.xml
# No citphrases found in: 06_1079.xml
# Processed and saved as JSON: 06_1080.xml
# Processed and saved as JSON: 06_1082.xml
# Processed and saved as JSON: 06_1083.xml
# Processed and saved as JSON: 06_1084.xml
# Processed and saved as JSON: 06_1085.xml
# Processed and saved as JSON: 06_1086.xml
# Processed and saved as JSON: 06_1088.xml
# Processed and saved as JSON: 06_1089.xml
# Processed and saved as JSON: 06_109.xml
# Processed and saved as JSON: 06_1095.xml
# Processed and saved as JSON: 06_1096.xml
# Processed and saved as JSON: 06_1097.xml
# Processed and saved as JSON: 06_1098.xml
# Processed and saved as JSON: 06_11.xml
# Processed and saved as JSON: 06_110.xml
# Processed and saved as JSON: 06_1101.xml
# Processed and saved as JSON: 06_1102.xml
# Processed and saved as JSON: 06_1104.xml
# Processed and saved as JSON: 06_1106.xml
# Processed and saved as JSON: 06_1110.xml
# Processed and saved as JSON: 06_1112.xml
# Processed and saved as JSON: 06_1113.xml
# Processed and saved as JSON: 06_1114.xml
# Processed and saved as JSON: 06_1115.xml
# No citphrases found in: 06_1116.xml
# Processed and saved as JSON: 06_1117.xml
# Processed and saved as JSON: 06_1119.xml
# Processed and saved as JSON: 06_112.xml
# No citphrases found in: 06_1120.xml
# No citphrases found in: 06_1121.xml
# Processed and saved as JSON: 06_1122.xml
# Processed and saved as JSON: 06_1124.xml
# Processed and saved as JSON: 06_1126.xml
# Processed and saved as JSON: 06_1129.xml
# Processed and saved as JSON: 06_1130.xml
# Processed and saved as JSON: 06_1134.xml
# No citphrases found in: 06_114.xml
# Processed and saved as JSON: 06_1140.xml
# Processed and saved as JSON: 06_1141.xml
# Processed and saved as JSON: 06_1142.xml
# Processed and saved as JSON: 06_1147.xml
# Processed and saved as JSON: 06_1156.xml
# No citphrases found in: 06_1158.xml
# Processed and saved as JSON: 06_1163.xml
# Processed and saved as JSON: 06_1164.xml
# Processed and saved as JSON: 06_1166.xml
# Processed and saved as JSON: 06_1168.xml
# Processed and saved as JSON: 06_1169.xml
# Processed and saved as JSON: 06_1170.xml
# Processed and saved as JSON: 06_1171.xml
# Processed and saved as JSON: 06_1172.xml
# Processed and saved as JSON: 06_1173.xml
# Processed and saved as JSON: 06_1174.xml
# Processed and saved as JSON: 06_1175.xml
# Processed and saved as JSON: 06_1176.xml
# Processed and saved as JSON: 06_1177.xml
# No citphrases found in: 06_118.xml
# Processed and saved as JSON: 06_1180.xml
# Processed and saved as JSON: 06_1181.xml
# No citphrases found in: 06_1183.xml
# Processed and saved as JSON: 06_1184.xml
# Processed and saved as JSON: 06_1186.xml
# No citphrases found in: 06_1187.xml
# Processed and saved as JSON: 06_1190.xml
# Processed and saved as JSON: 06_1193.xml
# Processed and saved as JSON: 06_1197.xml
# Processed and saved as JSON: 06_1198.xml
# Processed and saved as JSON: 06_1199.xml
# Processed and saved as JSON: 06_12.xml
# Processed and saved as JSON: 06_1200.xml
# Processed and saved as JSON: 06_1201.xml
# Processed and saved as JSON: 06_1202.xml
# Processed and saved as JSON: 06_1203.xml
# Processed and saved as JSON: 06_1209.xml
# Processed and saved as JSON: 06_121.xml
# Processed and saved as JSON: 06_1215.xml
# Processed and saved as JSON: 06_1216.xml
# Processed and saved as JSON: 06_1219.xml
# Processed and saved as JSON: 06_122.xml
# Processed and saved as JSON: 06_1220.xml
# Processed and saved as JSON: 06_1222.xml
# Processed and saved as JSON: 06_1223.xml
# Processed and saved as JSON: 06_1226.xml
# Processed and saved as JSON: 06_1227.xml
# Processed and saved as JSON: 06_1228.xml
# Processed and saved as JSON: 06_1229.xml
# Processed and saved as JSON: 06_1230.xml
# Processed and saved as JSON: 06_1234.xml
# Processed and saved as JSON: 06_1235.xml
# Processed and saved as JSON: 06_1236.xml
# Processed and saved as JSON: 06_1237.xml
# Processed and saved as JSON: 06_1239.xml
# Processed and saved as JSON: 06_124.xml
# Processed and saved as JSON: 06_1241.xml
# Processed and saved as JSON: 06_1242.xml
# Processed and saved as JSON: 06_1243.xml
# Processed and saved as JSON: 06_1244.xml
# Processed and saved as JSON: 06_1246.xml
# Processed and saved as JSON: 06_1247.xml
# Processed and saved as JSON: 06_1249.xml
# Processed and saved as JSON: 06_125.xml
# Processed and saved as JSON: 06_1250.xml
# Processed and saved as JSON: 06_1251.xml
# Processed and saved as JSON: 06_1252.xml
# Processed and saved as JSON: 06_1253.xml
# Processed and saved as JSON: 06_1254.xml
# No citphrases found in: 06_1255.xml
# Processed and saved as JSON: 06_1257.xml
# Processed and saved as JSON: 06_1259.xml
# Processed and saved as JSON: 06_126.xml
# Processed and saved as JSON: 06_1260.xml
# Processed and saved as JSON: 06_1261.xml
# Processed and saved as JSON: 06_1263.xml
# Processed and saved as JSON: 06_1264.xml
# Processed and saved as JSON: 06_1265.xml
# Processed and saved as JSON: 06_1267.xml
# Processed and saved as JSON: 06_1268.xml
# Processed and saved as JSON: 06_1269.xml
# Processed and saved as JSON: 06_1270.xml
# Processed and saved as JSON: 06_1271.xml
# Processed and saved as JSON: 06_1274.xml
# Processed and saved as JSON: 06_1275.xml
# Processed and saved as JSON: 06_1279.xml
# Processed and saved as JSON: 06_128.xml
# Processed and saved as JSON: 06_1280.xml
# Processed and saved as JSON: 06_1281.xml
# Processed and saved as JSON: 06_1285.xml
# No citphrases found in: 06_1287.xml
# Processed and saved as JSON: 06_1288.xml
# Processed and saved as JSON: 06_1289.xml
# Processed and saved as JSON: 06_129.xml
# Processed and saved as JSON: 06_1290.xml
# Processed and saved as JSON: 06_1291.xml
# Processed and saved as JSON: 06_1292.xml
# Processed and saved as JSON: 06_1293.xml
# Processed and saved as JSON: 06_1294.xml
# Processed and saved as JSON: 06_1295.xml
# Processed and saved as JSON: 06_1297.xml
# No citphrases found in: 06_1298.xml
# No citphrases found in: 06_1299.xml
# No citphrases found in: 06_13.xml
# Processed and saved as JSON: 06_1301.xml
# Processed and saved as JSON: 06_1302.xml
# Processed and saved as JSON: 06_1303.xml
# Processed and saved as JSON: 06_1305.xml
# No citphrases found in: 06_1307.xml
# Processed and saved as JSON: 06_1308.xml
# Processed and saved as JSON: 06_1309.xml
# Processed and saved as JSON: 06_131.xml
# Processed and saved as JSON: 06_1314.xml
# Processed and saved as JSON: 06_1317.xml
# Processed and saved as JSON: 06_1318.xml
# Processed and saved as JSON: 06_132.xml
# No citphrases found in: 06_1320.xml
# Processed and saved as JSON: 06_1321.xml
# Processed and saved as JSON: 06_1323.xml
# Processed and saved as JSON: 06_1324.xml
# Processed and saved as JSON: 06_1325.xml
# Processed and saved as JSON: 06_1326.xml
# Processed and saved as JSON: 06_1327.xml
# Processed and saved as JSON: 06_1328.xml
# Processed and saved as JSON: 06_1329.xml
# Processed and saved as JSON: 06_133.xml
# Processed and saved as JSON: 06_1330.xml
# Processed and saved as JSON: 06_1334.xml
# Processed and saved as JSON: 06_1335.xml
# Processed and saved as JSON: 06_1336.xml
# Processed and saved as JSON: 06_1338.xml
# Processed and saved as JSON: 06_1339.xml
# Processed and saved as JSON: 06_134.xml
# Processed and saved as JSON: 06_1340.xml
# Processed and saved as JSON: 06_1343.xml
# Processed and saved as JSON: 06_1346.xml
# Processed and saved as JSON: 06_1347.xml
# Processed and saved as JSON: 06_1348.xml
# Processed and saved as JSON: 06_135.xml
# No citphrases found in: 06_1350.xml
# Processed and saved as JSON: 06_1352.xml
# No citphrases found in: 06_1354.xml
# Processed and saved as JSON: 06_1355.xml
# Processed and saved as JSON: 06_1357.xml
# Processed and saved as JSON: 06_1358.xml
# No citphrases found in: 06_136.xml
# No citphrases found in: 06_1360.xml
# Processed and saved as JSON: 06_1361.xml
# Processed and saved as JSON: 06_1362.xml
# Processed and saved as JSON: 06_1363.xml
# Processed and saved as JSON: 06_1366.xml
# Processed and saved as JSON: 06_1367.xml
# Processed and saved as JSON: 06_1368.xml
# Processed and saved as JSON: 06_1369.xml
# Processed and saved as JSON: 06_137.xml
# No citphrases found in: 06_1370.xml
# Processed and saved as JSON: 06_1373.xml
# Processed and saved as JSON: 06_1374.xml
# Processed and saved as JSON: 06_1375.xml
# Processed and saved as JSON: 06_1376.xml
# Processed and saved as JSON: 06_1377.xml
# Processed and saved as JSON: 06_1379.xml
# Processed and saved as JSON: 06_1380.xml
# Processed and saved as JSON: 06_1381.xml
# Processed and saved as JSON: 06_1386.xml
# Processed and saved as JSON: 06_1387.xml
# Processed and saved as JSON: 06_1388.xml
# Processed and saved as JSON: 06_139.xml
# Processed and saved as JSON: 06_1390.xml
# Processed and saved as JSON: 06_1391.xml
# Processed and saved as JSON: 06_1392.xml
# Processed and saved as JSON: 06_1393.xml
# Processed and saved as JSON: 06_1394.xml
# Processed and saved as JSON: 06_1395.xml
# Processed and saved as JSON: 06_1396.xml
# Processed and saved as JSON: 06_1397.xml
# Processed and saved as JSON: 06_1398.xml
# Processed and saved as JSON: 06_1399.xml
# Processed and saved as JSON: 06_14.xml
# Processed and saved as JSON: 06_140.xml
# Processed and saved as JSON: 06_1400.xml
# Processed and saved as JSON: 06_1401.xml
# Processed and saved as JSON: 06_1402.xml
# Processed and saved as JSON: 06_1403.xml
# Processed and saved as JSON: 06_1404.xml
# Processed and saved as JSON: 06_1405.xml
# Processed and saved as JSON: 06_1406.xml
# Processed and saved as JSON: 06_1407.xml
# Processed and saved as JSON: 06_1408.xml
# Processed and saved as JSON: 06_1409.xml
# No citphrases found in: 06_1410.xml
# Processed and saved as JSON: 06_1411.xml
# Processed and saved as JSON: 06_1412.xml
# Processed and saved as JSON: 06_1413.xml
# Processed and saved as JSON: 06_1414.xml
# Processed and saved as JSON: 06_1415.xml
# Processed and saved as JSON: 06_1416.xml
# No citphrases found in: 06_1417.xml
# Processed and saved as JSON: 06_1418.xml
# Processed and saved as JSON: 06_1419.xml
# Processed and saved as JSON: 06_1420.xml
# Processed and saved as JSON: 06_1421.xml
# No citphrases found in: 06_1422.xml
# Processed and saved as JSON: 06_1426.xml
# Processed and saved as JSON: 06_143.xml
# Processed and saved as JSON: 06_1430.xml
# Processed and saved as JSON: 06_1431.xml
# No citphrases found in: 06_1432.xml
# Processed and saved as JSON: 06_1433.xml
# No citphrases found in: 06_1434.xml
# Processed and saved as JSON: 06_1435.xml
# Processed and saved as JSON: 06_1436.xml
# Processed and saved as JSON: 06_1437.xml
# Processed and saved as JSON: 06_1438.xml
# Processed and saved as JSON: 06_1439.xml
# Processed and saved as JSON: 06_1442.xml
# Processed and saved as JSON: 06_1443.xml
# Processed and saved as JSON: 06_1445.xml
# Processed and saved as JSON: 06_1446.xml
# No citphrases found in: 06_1447.xml
# Processed and saved as JSON: 06_1448.xml
# Processed and saved as JSON: 06_1449.xml
# Processed and saved as JSON: 06_1450.xml
# No citphrases found in: 06_1451.xml
# Processed and saved as JSON: 06_1452.xml
# Processed and saved as JSON: 06_1453.xml
# Processed and saved as JSON: 06_1454.xml
# Processed and saved as JSON: 06_1457.xml
# Processed and saved as JSON: 06_1458.xml
# Processed and saved as JSON: 06_1459.xml
# Processed and saved as JSON: 06_146.xml
# Processed and saved as JSON: 06_1462.xml
# No citphrases found in: 06_1463.xml
# Processed and saved as JSON: 06_1470.xml
# Processed and saved as JSON: 06_1472.xml
# Processed and saved as JSON: 06_1473.xml
# Processed and saved as JSON: 06_1474.xml
# Processed and saved as JSON: 06_1475.xml
# Processed and saved as JSON: 06_1477.xml
# Processed and saved as JSON: 06_1478.xml
# Processed and saved as JSON: 06_148.xml
# Processed and saved as JSON: 06_1480.xml
# Processed and saved as JSON: 06_1484.xml
# Processed and saved as JSON: 06_1489.xml
# Processed and saved as JSON: 06_1492.xml
# Processed and saved as JSON: 06_1493.xml
# Processed and saved as JSON: 06_1494.xml
# Processed and saved as JSON: 06_1495.xml
# Processed and saved as JSON: 06_1498.xml
# Processed and saved as JSON: 06_15.xml
# No citphrases found in: 06_1500.xml
# Processed and saved as JSON: 06_1504.xml
# No citphrases found in: 06_1505.xml
# Processed and saved as JSON: 06_1506.xml
# Processed and saved as JSON: 06_1507.xml
# Processed and saved as JSON: 06_1508.xml
# No citphrases found in: 06_1509.xml
# Processed and saved as JSON: 06_151.xml
# No citphrases found in: 06_1510.xml
# Processed and saved as JSON: 06_1514.xml
# Processed and saved as JSON: 06_1517.xml
# Processed and saved as JSON: 06_1519.xml
# Processed and saved as JSON: 06_152.xml
# Processed and saved as JSON: 06_1521.xml
# No citphrases found in: 06_1522.xml
# Processed and saved as JSON: 06_1523.xml
# Processed and saved as JSON: 06_1526.xml
# Processed and saved as JSON: 06_1529.xml
# Processed and saved as JSON: 06_1530.xml
# Processed and saved as JSON: 06_1531.xml
# Processed and saved as JSON: 06_1532.xml
# Processed and saved as JSON: 06_1533.xml
# Processed and saved as JSON: 06_1534.xml
# Processed and saved as JSON: 06_1535.xml
# Processed and saved as JSON: 06_1537.xml
# Processed and saved as JSON: 06_1538.xml
# Processed and saved as JSON: 06_1540.xml
# Processed and saved as JSON: 06_1541.xml
# Processed and saved as JSON: 06_1542.xml
# Processed and saved as JSON: 06_1543.xml
# Processed and saved as JSON: 06_1544.xml
# Processed and saved as JSON: 06_1545.xml
# Processed and saved as JSON: 06_1546.xml
# Processed and saved as JSON: 06_1547.xml
# Processed and saved as JSON: 06_1548.xml
# No citphrases found in: 06_1549.xml
# No citphrases found in: 06_1550.xml
# Processed and saved as JSON: 06_1551.xml
# Processed and saved as JSON: 06_1552.xml
# Processed and saved as JSON: 06_1553.xml
# Processed and saved as JSON: 06_1554.xml
# Processed and saved as JSON: 06_1555.xml
# Processed and saved as JSON: 06_1557.xml
# Processed and saved as JSON: 06_1561.xml
# Processed and saved as JSON: 06_1562.xml
# Processed and saved as JSON: 06_157.xml
# Processed and saved as JSON: 06_1571.xml
# Processed and saved as JSON: 06_1572.xml
# Processed and saved as JSON: 06_1573.xml
# Processed and saved as JSON: 06_1575.xml
# No citphrases found in: 06_1576.xml
# No citphrases found in: 06_1577.xml
# No citphrases found in: 06_1578.xml
# Processed and saved as JSON: 06_159.xml
# Processed and saved as JSON: 06_1590.xml
# Processed and saved as JSON: 06_1591.xml
# Processed and saved as JSON: 06_1592.xml
# Processed and saved as JSON: 06_1594.xml
# Processed and saved as JSON: 06_1596.xml
# Processed and saved as JSON: 06_1597.xml
# Processed and saved as JSON: 06_1598.xml
# Processed and saved as JSON: 06_16.xml
# Processed and saved as JSON: 06_160.xml
# Processed and saved as JSON: 06_1601.xml
# Processed and saved as JSON: 06_1608.xml
# Processed and saved as JSON: 06_1610.xml
# Processed and saved as JSON: 06_1611.xml
# Processed and saved as JSON: 06_1612.xml
# Processed and saved as JSON: 06_1614.xml
# Processed and saved as JSON: 06_1615.xml
# Processed and saved as JSON: 06_1616.xml
# Processed and saved as JSON: 06_1617.xml
# Processed and saved as JSON: 06_1619.xml
# Processed and saved as JSON: 06_162.xml
# Processed and saved as JSON: 06_1620.xml
# Processed and saved as JSON: 06_1624.xml
# Processed and saved as JSON: 06_1625.xml
# Processed and saved as JSON: 06_1628.xml
# Processed and saved as JSON: 06_163.xml
# Processed and saved as JSON: 06_1630.xml
# Processed and saved as JSON: 06_1632.xml
# Processed and saved as JSON: 06_1633.xml
# No citphrases found in: 06_1637.xml
# Processed and saved as JSON: 06_1638.xml
# Processed and saved as JSON: 06_1639.xml
# Processed and saved as JSON: 06_164.xml
# Processed and saved as JSON: 06_1640.xml
# Processed and saved as JSON: 06_1641.xml
# Processed and saved as JSON: 06_1642.xml
# Processed and saved as JSON: 06_1644.xml
# Processed and saved as JSON: 06_1645.xml
# Processed and saved as JSON: 06_1646.xml
# Processed and saved as JSON: 06_1648.xml
# Processed and saved as JSON: 06_1652.xml
# Processed and saved as JSON: 06_1653.xml
# Processed and saved as JSON: 06_1654.xml
# Processed and saved as JSON: 06_1655.xml
# Processed and saved as JSON: 06_1656.xml
# Processed and saved as JSON: 06_166.xml
# Processed and saved as JSON: 06_1663.xml
# Processed and saved as JSON: 06_1667.xml
# No citphrases found in: 06_1669.xml
# Processed and saved as JSON: 06_167.xml
# No citphrases found in: 06_1670.xml
# No citphrases found in: 06_1671.xml
# Processed and saved as JSON: 06_1672.xml
# Processed and saved as JSON: 06_1680.xml
# Processed and saved as JSON: 06_1681.xml
# Processed and saved as JSON: 06_1683.xml
# Processed and saved as JSON: 06_1685.xml
# Processed and saved as JSON: 06_1688.xml
# Processed and saved as JSON: 06_1689.xml
# No citphrases found in: 06_1691.xml
# Processed and saved as JSON: 06_1692.xml
# Processed and saved as JSON: 06_1694.xml
# No citphrases found in: 06_1695.xml
# Processed and saved as JSON: 06_1698.xml
# Processed and saved as JSON: 06_1699.xml
# Processed and saved as JSON: 06_17.xml
# Processed and saved as JSON: 06_1702.xml
# Processed and saved as JSON: 06_1703.xml
# Processed and saved as JSON: 06_1705.xml
# Processed and saved as JSON: 06_1706.xml
# Processed and saved as JSON: 06_1707.xml
# Processed and saved as JSON: 06_1708.xml
# No citphrases found in: 06_171.xml
# Processed and saved as JSON: 06_1710.xml
# Processed and saved as JSON: 06_1711.xml
# Processed and saved as JSON: 06_1712.xml
# No citphrases found in: 06_1714.xml
# Processed and saved as JSON: 06_1716.xml
# Processed and saved as JSON: 06_1718.xml
# Processed and saved as JSON: 06_172.xml
# Processed and saved as JSON: 06_1721.xml
# Processed and saved as JSON: 06_1722.xml
# Processed and saved as JSON: 06_1727.xml
# Processed and saved as JSON: 06_1728.xml
# Processed and saved as JSON: 06_1729.xml
# Processed and saved as JSON: 06_173.xml
# Processed and saved as JSON: 06_1730.xml
# Processed and saved as JSON: 06_1732.xml
# Processed and saved as JSON: 06_1733.xml
# Processed and saved as JSON: 06_1735.xml
# Processed and saved as JSON: 06_174.xml
# Processed and saved as JSON: 06_1744.xml
# Processed and saved as JSON: 06_1747.xml
# No citphrases found in: 06_1748.xml
# Processed and saved as JSON: 06_1749.xml
# Processed and saved as JSON: 06_175.xml
# Processed and saved as JSON: 06_1751.xml
# Processed and saved as JSON: 06_1755.xml
# Processed and saved as JSON: 06_1758.xml
# Processed and saved as JSON: 06_1759.xml
# Processed and saved as JSON: 06_176.xml
# Processed and saved as JSON: 06_1762.xml
# Processed and saved as JSON: 06_1763.xml
# Processed and saved as JSON: 06_1764.xml
# Processed and saved as JSON: 06_1768.xml
# Processed and saved as JSON: 06_1770.xml
# Processed and saved as JSON: 06_1771.xml
# Processed and saved as JSON: 06_1772.xml
# Processed and saved as JSON: 06_1773.xml
# Processed and saved as JSON: 06_1774.xml
# Processed and saved as JSON: 06_1777.xml
# Processed and saved as JSON: 06_1778.xml
# Processed and saved as JSON: 06_1779.xml
# No citphrases found in: 06_178.xml
# Processed and saved as JSON: 06_1780.xml
# Processed and saved as JSON: 06_1781.xml
# Processed and saved as JSON: 06_1782.xml
# Processed and saved as JSON: 06_1784.xml
# Processed and saved as JSON: 06_1785.xml
# Processed and saved as JSON: 06_1786.xml
# Processed and saved as JSON: 06_1787.xml
# Processed and saved as JSON: 06_1788.xml
# Processed and saved as JSON: 06_1790.xml
# Processed and saved as JSON: 06_1792.xml
# Processed and saved as JSON: 06_1796.xml
# Processed and saved as JSON: 06_1798.xml
# Processed and saved as JSON: 06_1799.xml
# Processed and saved as JSON: 06_18.xml
# Processed and saved as JSON: 06_180.xml
# Processed and saved as JSON: 06_1801.xml
# Processed and saved as JSON: 06_1802.xml
# Processed and saved as JSON: 06_1803.xml
# Processed and saved as JSON: 06_1804.xml
# Processed and saved as JSON: 06_1805.xml
# Processed and saved as JSON: 06_1806.xml
# Processed and saved as JSON: 06_1809.xml
# Processed and saved as JSON: 06_1810.xml
# No citphrases found in: 06_1811.xml
# Processed and saved as JSON: 06_1817.xml
# Processed and saved as JSON: 06_1819.xml
# Processed and saved as JSON: 06_1820.xml
# Processed and saved as JSON: 06_1825.xml
# Processed and saved as JSON: 06_1826.xml
# Processed and saved as JSON: 06_1829.xml
# No citphrases found in: 06_1833.xml
# Processed and saved as JSON: 06_1839.xml
# No citphrases found in: 06_1842.xml
# Processed and saved as JSON: 06_1846.xml
# Processed and saved as JSON: 06_1849.xml
# Processed and saved as JSON: 06_188.xml
# Processed and saved as JSON: 06_190.xml
# Processed and saved as JSON: 06_191.xml
# Processed and saved as JSON: 06_192.xml
# Processed and saved as JSON: 06_195.xml
# Processed and saved as JSON: 06_196.xml
# Processed and saved as JSON: 06_199.xml
# Processed and saved as JSON: 06_1999.xml
# Processed and saved as JSON: 06_2007.xml
# Processed and saved as JSON: 06_2008.xml
# Processed and saved as JSON: 06_2009.xml
# Processed and saved as JSON: 06_202.xml
# No citphrases found in: 06_206.xml
# Processed and saved as JSON: 06_208.xml
# Processed and saved as JSON: 06_209.xml
# Processed and saved as JSON: 06_21.xml
# Processed and saved as JSON: 06_212.xml
# Processed and saved as JSON: 06_213.xml
# No citphrases found in: 06_218.xml
# Processed and saved as JSON: 06_219.xml
# Processed and saved as JSON: 06_22.xml
# No citphrases found in: 06_220.xml
# Processed and saved as JSON: 06_221.xml
# Processed and saved as JSON: 06_222.xml
# Processed and saved as JSON: 06_224.xml
# Processed and saved as JSON: 06_228.xml
# No citphrases found in: 06_229.xml
# Processed and saved as JSON: 06_23.xml
# Processed and saved as JSON: 06_230.xml
# Processed and saved as JSON: 06_231.xml
# Processed and saved as JSON: 06_232.xml
# Processed and saved as JSON: 06_239.xml
# No citphrases found in: 06_240.xml
# Processed and saved as JSON: 06_241.xml
# Processed and saved as JSON: 06_242.xml
# No citphrases found in: 06_243.xml
# Processed and saved as JSON: 06_244.xml
# Processed and saved as JSON: 06_245.xml
# Processed and saved as JSON: 06_246.xml
# Processed and saved as JSON: 06_247.xml
# Processed and saved as JSON: 06_248.xml
# No citphrases found in: 06_249.xml
# Processed and saved as JSON: 06_25.xml
# Processed and saved as JSON: 06_251.xml
# Processed and saved as JSON: 06_254.xml
# Processed and saved as JSON: 06_256.xml
# Processed and saved as JSON: 06_258.xml
# Processed and saved as JSON: 06_259.xml
# Processed and saved as JSON: 06_26.xml
# Processed and saved as JSON: 06_263.xml
# Processed and saved as JSON: 06_264.xml
# Processed and saved as JSON: 06_267.xml
# Processed and saved as JSON: 06_269.xml
# No citphrases found in: 06_270.xml
# Processed and saved as JSON: 06_271.xml
# Processed and saved as JSON: 06_272.xml
# Processed and saved as JSON: 06_274.xml
# Processed and saved as JSON: 06_275.xml
# Processed and saved as JSON: 06_277.xml
# Processed and saved as JSON: 06_278.xml
# Processed and saved as JSON: 06_279.xml
# Processed and saved as JSON: 06_28.xml
# No citphrases found in: 06_280.xml
# Processed and saved as JSON: 06_286.xml
# Processed and saved as JSON: 06_287.xml
# Processed and saved as JSON: 06_288.xml
# Processed and saved as JSON: 06_3.xml
# No citphrases found in: 06_301.xml
# Processed and saved as JSON: 06_302.xml
# Processed and saved as JSON: 06_305.xml
# Processed and saved as JSON: 06_306.xml
# Processed and saved as JSON: 06_307.xml
# Processed and saved as JSON: 06_31.xml
# No citphrases found in: 06_311.xml
# Processed and saved as JSON: 06_314.xml
# Processed and saved as JSON: 06_315.xml
# Processed and saved as JSON: 06_316.xml
# Processed and saved as JSON: 06_318.xml
# Processed and saved as JSON: 06_32.xml
# Processed and saved as JSON: 06_322.xml
# Processed and saved as JSON: 06_324.xml
# Processed and saved as JSON: 06_325.xml
# Processed and saved as JSON: 06_326.xml
# Processed and saved as JSON: 06_327.xml
# Processed and saved as JSON: 06_328.xml
# Processed and saved as JSON: 06_33.xml
# Processed and saved as JSON: 06_330.xml
# No citphrases found in: 06_331.xml
# Processed and saved as JSON: 06_334.xml
# Processed and saved as JSON: 06_336.xml
# No citphrases found in: 06_338.xml
# Processed and saved as JSON: 06_34.xml
# Processed and saved as JSON: 06_341.xml
# Processed and saved as JSON: 06_342.xml
# Processed and saved as JSON: 06_343.xml
# Processed and saved as JSON: 06_348.xml
# Processed and saved as JSON: 06_349.xml
# Processed and saved as JSON: 06_35.xml
# Processed and saved as JSON: 06_350.xml
# No citphrases found in: 06_351.xml
# No citphrases found in: 06_352.xml
# Processed and saved as JSON: 06_354.xml
# Processed and saved as JSON: 06_355.xml
# Processed and saved as JSON: 06_356.xml
# Processed and saved as JSON: 06_36.xml
# Processed and saved as JSON: 06_360.xml
# Processed and saved as JSON: 06_361.xml
# Processed and saved as JSON: 06_362.xml
# Processed and saved as JSON: 06_363.xml
# Processed and saved as JSON: 06_364.xml
# Processed and saved as JSON: 06_366.xml
# Processed and saved as JSON: 06_367.xml
# Processed and saved as JSON: 06_37.xml
# Processed and saved as JSON: 06_371.xml
# Processed and saved as JSON: 06_373.xml
# Processed and saved as JSON: 06_376.xml
# Processed and saved as JSON: 06_377.xml
# Processed and saved as JSON: 06_378.xml
# Processed and saved as JSON: 06_379.xml
# Processed and saved as JSON: 06_38.xml
# No citphrases found in: 06_382.xml
# Processed and saved as JSON: 06_383.xml
# No citphrases found in: 06_384.xml
# Processed and saved as JSON: 06_385.xml
# Processed and saved as JSON: 06_386.xml
# Processed and saved as JSON: 06_387.xml
# Processed and saved as JSON: 06_388.xml
# No citphrases found in: 06_389.xml
# Processed and saved as JSON: 06_39.xml
# Processed and saved as JSON: 06_392.xml
# Processed and saved as JSON: 06_393.xml
# Processed and saved as JSON: 06_394.xml
# Processed and saved as JSON: 06_395.xml
# Processed and saved as JSON: 06_396.xml
# Processed and saved as JSON: 06_397.xml
# Processed and saved as JSON: 06_399.xml
# Processed and saved as JSON: 06_4.xml
# Processed and saved as JSON: 06_40.xml
# Processed and saved as JSON: 06_400.xml
# Processed and saved as JSON: 06_401.xml
# Processed and saved as JSON: 06_402.xml
# Processed and saved as JSON: 06_403.xml
# Processed and saved as JSON: 06_404.xml
# Processed and saved as JSON: 06_405.xml
# Processed and saved as JSON: 06_406.xml
# Processed and saved as JSON: 06_407.xml
# Processed and saved as JSON: 06_408.xml
# Processed and saved as JSON: 06_41.xml
# Processed and saved as JSON: 06_410.xml
# Processed and saved as JSON: 06_414.xml
# Processed and saved as JSON: 06_416.xml
# Processed and saved as JSON: 06_417.xml
# Processed and saved as JSON: 06_419.xml
# Processed and saved as JSON: 06_42.xml
# Processed and saved as JSON: 06_420.xml
# Processed and saved as JSON: 06_421.xml
# Processed and saved as JSON: 06_425.xml
# Processed and saved as JSON: 06_426.xml
# Processed and saved as JSON: 06_427.xml
# Processed and saved as JSON: 06_43.xml
# Processed and saved as JSON: 06_430.xml
# Processed and saved as JSON: 06_431.xml
# Processed and saved as JSON: 06_432.xml
# Processed and saved as JSON: 06_433.xml
# Processed and saved as JSON: 06_434.xml
# Processed and saved as JSON: 06_435.xml
# No citphrases found in: 06_436.xml
# Processed and saved as JSON: 06_437.xml
# Processed and saved as JSON: 06_438.xml
# Processed and saved as JSON: 06_44.xml
# Processed and saved as JSON: 06_440.xml
# Processed and saved as JSON: 06_442.xml
# Processed and saved as JSON: 06_443.xml
# Processed and saved as JSON: 06_444.xml
# Processed and saved as JSON: 06_445.xml
# Processed and saved as JSON: 06_446.xml
# No citphrases found in: 06_447.xml
# Processed and saved as JSON: 06_449.xml
# Processed and saved as JSON: 06_45.xml
# Processed and saved as JSON: 06_450.xml
# Processed and saved as JSON: 06_451.xml
# Processed and saved as JSON: 06_452.xml
# Processed and saved as JSON: 06_453.xml
# Processed and saved as JSON: 06_455.xml
# Processed and saved as JSON: 06_457.xml
# Processed and saved as JSON: 06_458.xml
# Processed and saved as JSON: 06_459.xml
# No citphrases found in: 06_46.xml
# Processed and saved as JSON: 06_460.xml
# Processed and saved as JSON: 06_462.xml
# Processed and saved as JSON: 06_463.xml
# No citphrases found in: 06_465.xml
# Processed and saved as JSON: 06_466.xml
# Processed and saved as JSON: 06_468.xml
# Processed and saved as JSON: 06_469.xml
# No citphrases found in: 06_47.xml
# Processed and saved as JSON: 06_470.xml
# Processed and saved as JSON: 06_472.xml
# Processed and saved as JSON: 06_473.xml
# Processed and saved as JSON: 06_475.xml
# Processed and saved as JSON: 06_478.xml
# Processed and saved as JSON: 06_481.xml
# Processed and saved as JSON: 06_484.xml
# Processed and saved as JSON: 06_487.xml
# Processed and saved as JSON: 06_488.xml
# Processed and saved as JSON: 06_489.xml
# No citphrases found in: 06_49.xml
# Processed and saved as JSON: 06_490.xml
# Processed and saved as JSON: 06_494.xml
# Processed and saved as JSON: 06_495.xml
# Processed and saved as JSON: 06_496.xml
# Processed and saved as JSON: 06_497.xml
# Processed and saved as JSON: 06_498.xml
# Processed and saved as JSON: 06_499.xml
# Processed and saved as JSON: 06_50.xml
# Processed and saved as JSON: 06_500.xml
# Processed and saved as JSON: 06_503.xml
# No citphrases found in: 06_505.xml
# Processed and saved as JSON: 06_506.xml
# Processed and saved as JSON: 06_507.xml
# No citphrases found in: 06_508.xml
# Processed and saved as JSON: 06_51.xml
# Processed and saved as JSON: 06_510.xml
# Processed and saved as JSON: 06_511.xml
# Processed and saved as JSON: 06_515.xml
# Processed and saved as JSON: 06_516.xml
# No citphrases found in: 06_517.xml
# Processed and saved as JSON: 06_518.xml
# Processed and saved as JSON: 06_519.xml
# Processed and saved as JSON: 06_52.xml
# Processed and saved as JSON: 06_520.xml
# Processed and saved as JSON: 06_522.xml
# Processed and saved as JSON: 06_524.xml
# Processed and saved as JSON: 06_525.xml
# Processed and saved as JSON: 06_526.xml
# Processed and saved as JSON: 06_527.xml
# Processed and saved as JSON: 06_531.xml
# Processed and saved as JSON: 06_532.xml
# Processed and saved as JSON: 06_533.xml
# Processed and saved as JSON: 06_536.xml
# Processed and saved as JSON: 06_538.xml
# No citphrases found in: 06_54.xml
# Processed and saved as JSON: 06_540.xml
# Processed and saved as JSON: 06_546.xml
# Processed and saved as JSON: 06_548.xml
# No citphrases found in: 06_551.xml
# Processed and saved as JSON: 06_552.xml
# Processed and saved as JSON: 06_555.xml
# Processed and saved as JSON: 06_559.xml
# Processed and saved as JSON: 06_56.xml
# Processed and saved as JSON: 06_57.xml
# Processed and saved as JSON: 06_571.xml
# Processed and saved as JSON: 06_573.xml
# Processed and saved as JSON: 06_574.xml
# Processed and saved as JSON: 06_575.xml
# Processed and saved as JSON: 06_58.xml
# Processed and saved as JSON: 06_582.xml
# Processed and saved as JSON: 06_584.xml
# Processed and saved as JSON: 06_587.xml
# Processed and saved as JSON: 06_588.xml
# Processed and saved as JSON: 06_589.xml
# Processed and saved as JSON: 06_59.xml
# Processed and saved as JSON: 06_590.xml
# Processed and saved as JSON: 06_591.xml
# Processed and saved as JSON: 06_592.xml
# Processed and saved as JSON: 06_598.xml
# Processed and saved as JSON: 06_6.xml
# Processed and saved as JSON: 06_60.xml
# Processed and saved as JSON: 06_600.xml
# Processed and saved as JSON: 06_601.xml
# Processed and saved as JSON: 06_603.xml
# Processed and saved as JSON: 06_606.xml
# Processed and saved as JSON: 06_607.xml
# Processed and saved as JSON: 06_609.xml
# Processed and saved as JSON: 06_61.xml
# No citphrases found in: 06_610.xml
# Processed and saved as JSON: 06_611.xml
# Processed and saved as JSON: 06_613.xml
# Processed and saved as JSON: 06_616.xml
# Processed and saved as JSON: 06_617.xml
# Processed and saved as JSON: 06_618.xml
# No citphrases found in: 06_619.xml
# Processed and saved as JSON: 06_622.xml
# Processed and saved as JSON: 06_623.xml
# Processed and saved as JSON: 06_624.xml
# Processed and saved as JSON: 06_626.xml
# Processed and saved as JSON: 06_627.xml
# Processed and saved as JSON: 06_63.xml
# Processed and saved as JSON: 06_630.xml
# Processed and saved as JSON: 06_632.xml
# Processed and saved as JSON: 06_633.xml
# Processed and saved as JSON: 06_635.xml
# Processed and saved as JSON: 06_636.xml
# Processed and saved as JSON: 06_637.xml
# Processed and saved as JSON: 06_639.xml
# Processed and saved as JSON: 06_640.xml
# Processed and saved as JSON: 06_641.xml
# Processed and saved as JSON: 06_642.xml
# Processed and saved as JSON: 06_643.xml
# Processed and saved as JSON: 06_644.xml
# Processed and saved as JSON: 06_646.xml
# Processed and saved as JSON: 06_647.xml
# Processed and saved as JSON: 06_648.xml
# Processed and saved as JSON: 06_649.xml
# Processed and saved as JSON: 06_650.xml
# Processed and saved as JSON: 06_651.xml
# Processed and saved as JSON: 06_652.xml
# Processed and saved as JSON: 06_653.xml
# Processed and saved as JSON: 06_655.xml
# Processed and saved as JSON: 06_656.xml
# Processed and saved as JSON: 06_657.xml
# Processed and saved as JSON: 06_659.xml
# Processed and saved as JSON: 06_66.xml
# Processed and saved as JSON: 06_660.xml
# Processed and saved as JSON: 06_661.xml
# Processed and saved as JSON: 06_662.xml
# Processed and saved as JSON: 06_663.xml
# No citphrases found in: 06_664.xml
# Processed and saved as JSON: 06_666.xml
# Processed and saved as JSON: 06_668.xml
# Processed and saved as JSON: 06_67.xml
# Processed and saved as JSON: 06_670.xml
# Processed and saved as JSON: 06_671.xml
# Processed and saved as JSON: 06_672.xml
# Processed and saved as JSON: 06_675.xml
# Processed and saved as JSON: 06_679.xml
# Processed and saved as JSON: 06_68.xml
# Processed and saved as JSON: 06_682.xml
# Processed and saved as JSON: 06_684.xml
# Processed and saved as JSON: 06_685.xml
# Processed and saved as JSON: 06_686.xml
# Processed and saved as JSON: 06_688.xml
# Processed and saved as JSON: 06_693.xml
# Processed and saved as JSON: 06_695.xml
# Processed and saved as JSON: 06_696.xml
# Processed and saved as JSON: 06_699.xml
# Processed and saved as JSON: 06_7.xml
# No citphrases found in: 06_70.xml
# Processed and saved as JSON: 06_700.xml
# Processed and saved as JSON: 06_701.xml
# Processed and saved as JSON: 06_702.xml
# No citphrases found in: 06_703.xml
# Processed and saved as JSON: 06_704.xml
# Processed and saved as JSON: 06_705.xml
# Processed and saved as JSON: 06_706.xml
# Processed and saved as JSON: 06_707.xml
# Processed and saved as JSON: 06_708.xml
# Processed and saved as JSON: 06_709.xml
# Processed and saved as JSON: 06_71.xml
# Processed and saved as JSON: 06_710.xml
# Processed and saved as JSON: 06_711.xml
# Processed and saved as JSON: 06_713.xml
# Processed and saved as JSON: 06_714.xml
# Processed and saved as JSON: 06_715.xml
# Processed and saved as JSON: 06_717.xml
# Processed and saved as JSON: 06_719.xml
# Processed and saved as JSON: 06_721.xml
# Processed and saved as JSON: 06_722.xml
# Processed and saved as JSON: 06_723.xml
# Processed and saved as JSON: 06_724.xml
# Processed and saved as JSON: 06_725.xml
# Processed and saved as JSON: 06_726.xml
# Processed and saved as JSON: 06_727.xml
# Processed and saved as JSON: 06_728.xml
# Processed and saved as JSON: 06_729.xml
# Processed and saved as JSON: 06_732.xml
# Processed and saved as JSON: 06_733.xml
# Processed and saved as JSON: 06_734.xml
# Processed and saved as JSON: 06_735.xml
# Processed and saved as JSON: 06_736.xml
# Processed and saved as JSON: 06_737.xml
# Processed and saved as JSON: 06_739.xml
# Processed and saved as JSON: 06_74.xml
# Processed and saved as JSON: 06_740.xml
# No citphrases found in: 06_741.xml
# Processed and saved as JSON: 06_743.xml
# Processed and saved as JSON: 06_745.xml
# Processed and saved as JSON: 06_748.xml
# Processed and saved as JSON: 06_752.xml
# Processed and saved as JSON: 06_754.xml
# Processed and saved as JSON: 06_755.xml
# Processed and saved as JSON: 06_757.xml
# Processed and saved as JSON: 06_758.xml
# Processed and saved as JSON: 06_759.xml
# Processed and saved as JSON: 06_76.xml
# Processed and saved as JSON: 06_760.xml
# Processed and saved as JSON: 06_761.xml
# Processed and saved as JSON: 06_765.xml
# Processed and saved as JSON: 06_766.xml
# Processed and saved as JSON: 06_767.xml
# Processed and saved as JSON: 06_768.xml
# Processed and saved as JSON: 06_769.xml
# Processed and saved as JSON: 06_77.xml
# Processed and saved as JSON: 06_772.xml
# Processed and saved as JSON: 06_773.xml
# Processed and saved as JSON: 06_774.xml
# Processed and saved as JSON: 06_779.xml
# Processed and saved as JSON: 06_78.xml
# Processed and saved as JSON: 06_780.xml
# Processed and saved as JSON: 06_781.xml
# Processed and saved as JSON: 06_782.xml
# Processed and saved as JSON: 06_783.xml
# Processed and saved as JSON: 06_784.xml
# Processed and saved as JSON: 06_786.xml
# Processed and saved as JSON: 06_788.xml
# Processed and saved as JSON: 06_79.xml
# No citphrases found in: 06_790.xml
# Processed and saved as JSON: 06_792.xml
# Processed and saved as JSON: 06_793.xml
# Processed and saved as JSON: 06_8.xml
# Processed and saved as JSON: 06_802.xml
# Processed and saved as JSON: 06_805.xml
# Processed and saved as JSON: 06_807.xml
# No citphrases found in: 06_808.xml
# Processed and saved as JSON: 06_809.xml
# Processed and saved as JSON: 06_810.xml
# Processed and saved as JSON: 06_811.xml
# Processed and saved as JSON: 06_812.xml
# Processed and saved as JSON: 06_813.xml
# Processed and saved as JSON: 06_814.xml
# Processed and saved as JSON: 06_815.xml
# Processed and saved as JSON: 06_816.xml
# Processed and saved as JSON: 06_818.xml
# Processed and saved as JSON: 06_819.xml
# Processed and saved as JSON: 06_82.xml
# Processed and saved as JSON: 06_821.xml
# Processed and saved as JSON: 06_822.xml
# Processed and saved as JSON: 06_823.xml
# Processed and saved as JSON: 06_825.xml
# Processed and saved as JSON: 06_826.xml
# Processed and saved as JSON: 06_828.xml
# Processed and saved as JSON: 06_83.xml
# No citphrases found in: 06_831.xml
# Processed and saved as JSON: 06_832.xml
# Processed and saved as JSON: 06_833.xml
# Processed and saved as JSON: 06_834.xml
# Processed and saved as JSON: 06_836.xml
# Processed and saved as JSON: 06_838.xml
# Processed and saved as JSON: 06_840.xml
# Processed and saved as JSON: 06_842.xml
# Processed and saved as JSON: 06_843.xml
# Processed and saved as JSON: 06_844.xml
# Processed and saved as JSON: 06_845.xml
# Processed and saved as JSON: 06_846.xml
# Processed and saved as JSON: 06_847.xml
# Processed and saved as JSON: 06_848.xml
# Processed and saved as JSON: 06_849.xml
# Processed and saved as JSON: 06_85.xml
# Processed and saved as JSON: 06_850.xml
# Processed and saved as JSON: 06_851.xml
# Processed and saved as JSON: 06_852.xml
# No citphrases found in: 06_86.xml
# Processed and saved as JSON: 06_862.xml
# Processed and saved as JSON: 06_863.xml
# Processed and saved as JSON: 06_868.xml
# Processed and saved as JSON: 06_869.xml
# No citphrases found in: 06_87.xml
# Processed and saved as JSON: 06_872.xml
# No citphrases found in: 06_88.xml
# Processed and saved as JSON: 06_880.xml
# Processed and saved as JSON: 06_881.xml
# Processed and saved as JSON: 06_882.xml
# Processed and saved as JSON: 06_884.xml
# Processed and saved as JSON: 06_885.xml
# Processed and saved as JSON: 06_886.xml
# Processed and saved as JSON: 06_887.xml
# Processed and saved as JSON: 06_888.xml
# Processed and saved as JSON: 06_889.xml
# No citphrases found in: 06_89.xml
# Processed and saved as JSON: 06_890.xml
# Processed and saved as JSON: 06_891.xml
# No citphrases found in: 06_892.xml
# Processed and saved as JSON: 06_893.xml
# Processed and saved as JSON: 06_895.xml
# No citphrases found in: 06_896.xml
# Processed and saved as JSON: 06_897.xml
# Processed and saved as JSON: 06_898.xml
# Processed and saved as JSON: 06_899.xml
# Processed and saved as JSON: 06_9.xml
# Processed and saved as JSON: 06_90.xml
# Processed and saved as JSON: 06_900.xml
# Processed and saved as JSON: 06_901.xml
# Processed and saved as JSON: 06_902.xml
# Processed and saved as JSON: 06_903.xml
# No citphrases found in: 06_904.xml
# Processed and saved as JSON: 06_905.xml
# Processed and saved as JSON: 06_906.xml
# Processed and saved as JSON: 06_907.xml
# Processed and saved as JSON: 06_908.xml
# Processed and saved as JSON: 06_91.xml
# Processed and saved as JSON: 06_912.xml
# Processed and saved as JSON: 06_913.xml
# Processed and saved as JSON: 06_914.xml
# Processed and saved as JSON: 06_916.xml
# Processed and saved as JSON: 06_917.xml
# Processed and saved as JSON: 06_918.xml
# Processed and saved as JSON: 06_92.xml
# Processed and saved as JSON: 06_920.xml
# No citphrases found in: 06_921.xml
# Processed and saved as JSON: 06_923.xml
# Processed and saved as JSON: 06_925.xml
# Processed and saved as JSON: 06_927.xml
# Processed and saved as JSON: 06_93.xml
# Processed and saved as JSON: 06_930.xml
# Processed and saved as JSON: 06_931.xml
# Processed and saved as JSON: 06_933.xml
# Processed and saved as JSON: 06_934.xml
# Processed and saved as JSON: 06_935.xml
# Processed and saved as JSON: 06_936.xml
# Processed and saved as JSON: 06_937.xml
# Processed and saved as JSON: 06_939.xml
# Processed and saved as JSON: 06_94.xml
# Processed and saved as JSON: 06_941.xml
# Processed and saved as JSON: 06_942.xml
# Processed and saved as JSON: 06_943.xml
# Processed and saved as JSON: 06_944.xml
# Processed and saved as JSON: 06_945.xml
# Processed and saved as JSON: 06_946.xml
# Processed and saved as JSON: 06_948.xml
# Processed and saved as JSON: 06_949.xml
# Processed and saved as JSON: 06_954.xml
# Processed and saved as JSON: 06_955.xml
# Processed and saved as JSON: 06_958.xml
# Processed and saved as JSON: 06_96.xml
# Processed and saved as JSON: 06_961.xml
# No citphrases found in: 06_963.xml
# Processed and saved as JSON: 06_964.xml
# Processed and saved as JSON: 06_965.xml
# Processed and saved as JSON: 06_966.xml
# Processed and saved as JSON: 06_967.xml
# Processed and saved as JSON: 06_969.xml
# Processed and saved as JSON: 06_97.xml
# Processed and saved as JSON: 06_972.xml
# Processed and saved as JSON: 06_979.xml
# No citphrases found in: 06_98.xml
# Processed and saved as JSON: 06_980.xml
# Processed and saved as JSON: 06_981.xml
# Processed and saved as JSON: 06_994.xml
# Processed and saved as JSON: 06_996.xml
# Processed and saved as JSON: 06_999.xml
# Processed and saved as JSON: 07_1.xml
# Processed and saved as JSON: 07_10.xml
# Processed and saved as JSON: 07_1000.xml
# Processed and saved as JSON: 07_1001.xml
# Processed and saved as JSON: 07_1003.xml
# Processed and saved as JSON: 07_1004.xml
# Processed and saved as JSON: 07_1006.xml
# Processed and saved as JSON: 07_1007.xml
# Processed and saved as JSON: 07_1009.xml
# Processed and saved as JSON: 07_1010.xml
# Processed and saved as JSON: 07_1011.xml
# Processed and saved as JSON: 07_1012.xml
# No citphrases found in: 07_1014.xml
# No citphrases found in: 07_1015.xml
# Processed and saved as JSON: 07_1025.xml
# Processed and saved as JSON: 07_1026.xml
# Processed and saved as JSON: 07_1027.xml
# Processed and saved as JSON: 07_1028.xml
# No citphrases found in: 07_1029.xml
# Processed and saved as JSON: 07_103.xml
# Processed and saved as JSON: 07_1030.xml
# Processed and saved as JSON: 07_1031.xml
# Processed and saved as JSON: 07_1037.xml
# No citphrases found in: 07_1038.xml
# Processed and saved as JSON: 07_104.xml
# Processed and saved as JSON: 07_1040.xml
# Processed and saved as JSON: 07_1041.xml
# Processed and saved as JSON: 07_1042.xml
# Processed and saved as JSON: 07_1044.xml
# Processed and saved as JSON: 07_1047.xml
# Processed and saved as JSON: 07_1048.xml
# Processed and saved as JSON: 07_105.xml
# Processed and saved as JSON: 07_1051.xml
# Processed and saved as JSON: 07_1052.xml
# Processed and saved as JSON: 07_1054.xml
# Processed and saved as JSON: 07_1055.xml
# Processed and saved as JSON: 07_1057.xml
# Processed and saved as JSON: 07_1058.xml
# Processed and saved as JSON: 07_1059.xml
# Processed and saved as JSON: 07_1061.xml
# Processed and saved as JSON: 07_1062.xml
# Processed and saved as JSON: 07_1063.xml
# Processed and saved as JSON: 07_1066.xml
# Processed and saved as JSON: 07_1069.xml
# Processed and saved as JSON: 07_1072.xml
# Processed and saved as JSON: 07_1075.xml
# Processed and saved as JSON: 07_1076.xml
# Processed and saved as JSON: 07_1078.xml
# Processed and saved as JSON: 07_1079.xml
# Processed and saved as JSON: 07_1080.xml
# Processed and saved as JSON: 07_1081.xml
# Processed and saved as JSON: 07_1082.xml
# No citphrases found in: 07_1084.xml
# Processed and saved as JSON: 07_1085.xml
# Processed and saved as JSON: 07_1087.xml
# Processed and saved as JSON: 07_1088.xml
# Processed and saved as JSON: 07_1090.xml
# Processed and saved as JSON: 07_1091.xml
# Processed and saved as JSON: 07_1092.xml
# Processed and saved as JSON: 07_1095.xml
# Processed and saved as JSON: 07_1098.xml
# Processed and saved as JSON: 07_11.xml
# Processed and saved as JSON: 07_1100.xml
# Processed and saved as JSON: 07_1104.xml
# Processed and saved as JSON: 07_1108.xml
# No citphrases found in: 07_111.xml
# Processed and saved as JSON: 07_1123.xml
# Processed and saved as JSON: 07_1126.xml
# Processed and saved as JSON: 07_1129.xml
# Processed and saved as JSON: 07_1132.xml
# Processed and saved as JSON: 07_1133.xml
# Processed and saved as JSON: 07_1136.xml
# Processed and saved as JSON: 07_1138.xml
# Processed and saved as JSON: 07_1139.xml
# Processed and saved as JSON: 07_114.xml
# Processed and saved as JSON: 07_1140.xml
# Processed and saved as JSON: 07_1141.xml
# Processed and saved as JSON: 07_1142.xml
# Processed and saved as JSON: 07_1154.xml
# Processed and saved as JSON: 07_1159.xml
# Processed and saved as JSON: 07_1161.xml
# Processed and saved as JSON: 07_1162.xml
# Processed and saved as JSON: 07_1165.xml
# Processed and saved as JSON: 07_1167.xml
# Processed and saved as JSON: 07_1171.xml
# Processed and saved as JSON: 07_1172.xml
# Processed and saved as JSON: 07_1173.xml
# Processed and saved as JSON: 07_1174.xml
# Processed and saved as JSON: 07_1175.xml
# No citphrases found in: 07_1176.xml
# Processed and saved as JSON: 07_1178.xml
# Processed and saved as JSON: 07_1179.xml
# Processed and saved as JSON: 07_1182.xml
# Processed and saved as JSON: 07_1183.xml
# Processed and saved as JSON: 07_1184.xml
# Processed and saved as JSON: 07_1185.xml
# Processed and saved as JSON: 07_1188.xml
# Processed and saved as JSON: 07_1189.xml
# Processed and saved as JSON: 07_1191.xml
# Processed and saved as JSON: 07_1192.xml
# Processed and saved as JSON: 07_1193.xml
# Processed and saved as JSON: 07_1194.xml
# Processed and saved as JSON: 07_1195.xml
# Processed and saved as JSON: 07_1197.xml
# Processed and saved as JSON: 07_1199.xml
# Processed and saved as JSON: 07_1203.xml
# Processed and saved as JSON: 07_1204.xml
# Processed and saved as JSON: 07_1205.xml
# Processed and saved as JSON: 07_121.xml
# Processed and saved as JSON: 07_1212.xml
# Processed and saved as JSON: 07_1216.xml
# Processed and saved as JSON: 07_1218.xml
# Processed and saved as JSON: 07_122.xml
# No citphrases found in: 07_1220.xml
# Processed and saved as JSON: 07_1221.xml
# Processed and saved as JSON: 07_1224.xml
# Processed and saved as JSON: 07_1225.xml
# Processed and saved as JSON: 07_1226.xml
# Processed and saved as JSON: 07_123.xml
# Processed and saved as JSON: 07_1234.xml
# Processed and saved as JSON: 07_1236.xml
# Processed and saved as JSON: 07_124.xml
# Processed and saved as JSON: 07_1242.xml
# Processed and saved as JSON: 07_1243.xml
# Processed and saved as JSON: 07_1244.xml
# Processed and saved as JSON: 07_1245.xml
# Processed and saved as JSON: 07_1246.xml
# ...
# Processed and saved as JSON: 09_356.xml
# Processed and saved as JSON: 09_36.xml
# Processed and saved as JSON: 09_361.xml
# Processed and saved as JSON: 09_362.xml
# Processed and saved as JSON: 09_363.xml
# Processed and saved as JSON: 09_364.xml
# Processed and saved as JSON: 09_367.xml
# Processed and saved as JSON: 09_368.xml
# Processed and saved as JSON: 09_37.xml
# Processed and saved as JSON: 09_370.xml
# Processed and saved as JSON: 09_372.xml
# Processed and saved as JSON: 09_374.xml
# No citphrases found in: 09_376.xml
# Processed and saved as JSON: 09_38.xml
# Processed and saved as JSON: 09_385.xml
# Processed and saved as JSON: 09_388.xml
# Processed and saved as JSON: 09_389.xml
# Processed and saved as JSON: 09_39.xml
# Processed and saved as JSON: 09_390.xml
# Processed and saved as JSON: 09_392.xml
# Processed and saved as JSON: 09_393.xml
# No citphrases found in: 09_394.xml
# Processed and saved as JSON: 09_395.xml
# Processed and saved as JSON: 09_399.xml
# Processed and saved as JSON: 09_40.xml
# Processed and saved as JSON: 09_400.xml
# Processed and saved as JSON: 09_401.xml
# Processed and saved as JSON: 09_402.xml
# Processed and saved as JSON: 09_403.xml
# Processed and saved as JSON: 09_404.xml
# Processed and saved as JSON: 09_41.xml
# Processed and saved as JSON: 09_410.xml
# Processed and saved as JSON: 09_411.xml
# Processed and saved as JSON: 09_413.xml
# Processed and saved as JSON: 09_415.xml
# Processed and saved as JSON: 09_42.xml
# Processed and saved as JSON: 09_422.xml
# Processed and saved as JSON: 09_426.xml
# Processed and saved as JSON: 09_427.xml
# Processed and saved as JSON: 09_428.xml
# Processed and saved as JSON: 09_429.xml
# Processed and saved as JSON: 09_43.xml
# Processed and saved as JSON: 09_432.xml
# Processed and saved as JSON: 09_433.xml
# Processed and saved as JSON: 09_437.xml
# Processed and saved as JSON: 09_438.xml
# Processed and saved as JSON: 09_439.xml
# Processed and saved as JSON: 09_44.xml
# Processed and saved as JSON: 09_441.xml
# Processed and saved as JSON: 09_446.xml
# Processed and saved as JSON: 09_447.xml
# Processed and saved as JSON: 09_448.xml
# Processed and saved as JSON: 09_449.xml
# Processed and saved as JSON: 09_450.xml
# Processed and saved as JSON: 09_451.xml
# Processed and saved as JSON: 09_452.xml
# No citphrases found in: 09_453.xml
# Processed and saved as JSON: 09_46.xml
# No citphrases found in: 09_462.xml
# Processed and saved as JSON: 09_465.xml
# Processed and saved as JSON: 09_466.xml
# Processed and saved as JSON: 09_467.xml
# No citphrases found in: 09_469.xml
# Processed and saved as JSON: 09_474.xml
# Processed and saved as JSON: 09_475.xml
# Processed and saved as JSON: 09_476.xml
# Processed and saved as JSON: 09_477.xml
# Processed and saved as JSON: 09_479.xml
# Processed and saved as JSON: 09_480.xml
# Processed and saved as JSON: 09_481.xml
# Processed and saved as JSON: 09_484.xml
# Processed and saved as JSON: 09_485.xml
# Processed and saved as JSON: 09_486.xml
# Processed and saved as JSON: 09_487.xml
# No citphrases found in: 09_489.xml
# Processed and saved as JSON: 09_49.xml
# Processed and saved as JSON: 09_490.xml
# Processed and saved as JSON: 09_494.xml
# No citphrases found in: 09_496.xml
# Processed and saved as JSON: 09_498.xml
# Processed and saved as JSON: 09_499.xml
# Processed and saved as JSON: 09_502.xml
# Processed and saved as JSON: 09_504.xml
# Processed and saved as JSON: 09_507.xml
# No citphrases found in: 09_509.xml
# No citphrases found in: 09_51.xml
# Processed and saved as JSON: 09_510.xml
# Processed and saved as JSON: 09_513.xml
# Processed and saved as JSON: 09_514.xml
# Processed and saved as JSON: 09_515.xml
# Processed and saved as JSON: 09_516.xml
# Processed and saved as JSON: 09_517.xml
# Processed and saved as JSON: 09_519.xml
# Processed and saved as JSON: 09_52.xml
# Processed and saved as JSON: 09_521.xml
# Processed and saved as JSON: 09_522.xml
# Processed and saved as JSON: 09_523.xml
# Processed and saved as JSON: 09_526.xml
# Processed and saved as JSON: 09_528.xml
# Processed and saved as JSON: 09_529.xml
# Processed and saved as JSON: 09_53.xml
# Processed and saved as JSON: 09_530.xml
# Processed and saved as JSON: 09_532.xml
# Processed and saved as JSON: 09_533.xml
# Processed and saved as JSON: 09_534.xml
# Processed and saved as JSON: 09_537.xml
# Processed and saved as JSON: 09_538.xml
# Processed and saved as JSON: 09_539.xml
# Processed and saved as JSON: 09_54.xml
# Processed and saved as JSON: 09_540.xml
# Processed and saved as JSON: 09_541.xml
# Processed and saved as JSON: 09_542.xml
# Processed and saved as JSON: 09_543.xml
# Processed and saved as JSON: 09_545.xml
# Processed and saved as JSON: 09_546.xml
# No citphrases found in: 09_547.xml
# Processed and saved as JSON: 09_548.xml
# Processed and saved as JSON: 09_549.xml
# Processed and saved as JSON: 09_551.xml
# Processed and saved as JSON: 09_552.xml
# No citphrases found in: 09_553.xml
# Processed and saved as JSON: 09_554.xml
# Processed and saved as JSON: 09_555.xml
# Processed and saved as JSON: 09_556.xml
# Processed and saved as JSON: 09_558.xml
# Processed and saved as JSON: 09_559.xml
# Processed and saved as JSON: 09_56.xml
# Processed and saved as JSON: 09_560.xml
# Processed and saved as JSON: 09_561.xml
# Processed and saved as JSON: 09_562.xml
# Processed and saved as JSON: 09_563.xml
# Processed and saved as JSON: 09_564.xml
# Processed and saved as JSON: 09_567.xml
# Processed and saved as JSON: 09_57.xml
# No citphrases found in: 09_570.xml
# Processed and saved as JSON: 09_571.xml
# Processed and saved as JSON: 09_572.xml
# Processed and saved as JSON: 09_577.xml
# Processed and saved as JSON: 09_578.xml
# Processed and saved as JSON: 09_579.xml
# Processed and saved as JSON: 09_58.xml
# Processed and saved as JSON: 09_580.xml
# No citphrases found in: 09_584.xml
# Processed and saved as JSON: 09_585.xml
# Processed and saved as JSON: 09_586.xml
# Processed and saved as JSON: 09_59.xml
# Processed and saved as JSON: 09_590.xml
# Processed and saved as JSON: 09_593.xml
# Processed and saved as JSON: 09_596.xml
# Processed and saved as JSON: 09_597.xml
# Processed and saved as JSON: 09_599.xml
# Processed and saved as JSON: 09_6.xml
# Processed and saved as JSON: 09_60.xml
# Processed and saved as JSON: 09_600.xml
# Processed and saved as JSON: 09_601.xml
# Processed and saved as JSON: 09_604.xml
# Processed and saved as JSON: 09_605.xml
# Processed and saved as JSON: 09_606.xml
# Processed and saved as JSON: 09_608.xml
# Processed and saved as JSON: 09_609.xml
# Processed and saved as JSON: 09_61.xml
# No citphrases found in: 09_610.xml
# Processed and saved as JSON: 09_613.xml
# Processed and saved as JSON: 09_618.xml
# Processed and saved as JSON: 09_619.xml
# Processed and saved as JSON: 09_62.xml
# Processed and saved as JSON: 09_620.xml
# Processed and saved as JSON: 09_622.xml
# No citphrases found in: 09_625.xml
# Processed and saved as JSON: 09_629.xml
# Processed and saved as JSON: 09_63.xml
# Processed and saved as JSON: 09_632.xml
# No citphrases found in: 09_634.xml
# Processed and saved as JSON: 09_636.xml
# Processed and saved as JSON: 09_637.xml
# Processed and saved as JSON: 09_639.xml
# Processed and saved as JSON: 09_64.xml
# Processed and saved as JSON: 09_642.xml
# Processed and saved as JSON: 09_644.xml
# Processed and saved as JSON: 09_645.xml
# Processed and saved as JSON: 09_646.xml
# Processed and saved as JSON: 09_647.xml
# Processed and saved as JSON: 09_650.xml
# Processed and saved as JSON: 09_652.xml
# Processed and saved as JSON: 09_654.xml
# Processed and saved as JSON: 09_656.xml
# Processed and saved as JSON: 09_657.xml
# Processed and saved as JSON: 09_658.xml
# Processed and saved as JSON: 09_660.xml
# Processed and saved as JSON: 09_661.xml
# Processed and saved as JSON: 09_662.xml
# Processed and saved as JSON: 09_666.xml
# Processed and saved as JSON: 09_667.xml
# Processed and saved as JSON: 09_668.xml
# Processed and saved as JSON: 09_669.xml
# Processed and saved as JSON: 09_670.xml
# Processed and saved as JSON: 09_672.xml
# Processed and saved as JSON: 09_673.xml
# Processed and saved as JSON: 09_675.xml
# Processed and saved as JSON: 09_676.xml
# Processed and saved as JSON: 09_677.xml
# Processed and saved as JSON: 09_678.xml
# Processed and saved as JSON: 09_679.xml
# Processed and saved as JSON: 09_68.xml
# Processed and saved as JSON: 09_680.xml
# No citphrases found in: 09_681.xml
# Processed and saved as JSON: 09_682.xml
# Processed and saved as JSON: 09_683.xml
# Processed and saved as JSON: 09_684.xml
# Processed and saved as JSON: 09_686.xml
# Processed and saved as JSON: 09_689.xml
# Processed and saved as JSON: 09_69.xml
# Processed and saved as JSON: 09_694.xml
# Processed and saved as JSON: 09_698.xml
# No citphrases found in: 09_699.xml
# Processed and saved as JSON: 09_7.xml
# Processed and saved as JSON: 09_70.xml
# Processed and saved as JSON: 09_700.xml
# Processed and saved as JSON: 09_701.xml
# Processed and saved as JSON: 09_702.xml
# Processed and saved as JSON: 09_704.xml
# Processed and saved as JSON: 09_709.xml
# Processed and saved as JSON: 09_71.xml
# Processed and saved as JSON: 09_710.xml
# No citphrases found in: 09_711.xml
# Processed and saved as JSON: 09_712.xml
# No citphrases found in: 09_714.xml
# Processed and saved as JSON: 09_715.xml
# Processed and saved as JSON: 09_717.xml
# Processed and saved as JSON: 09_718.xml
# Processed and saved as JSON: 09_72.xml
# Processed and saved as JSON: 09_721.xml
# Processed and saved as JSON: 09_722.xml
# No citphrases found in: 09_724.xml
# Processed and saved as JSON: 09_726.xml
# Processed and saved as JSON: 09_727.xml
# Processed and saved as JSON: 09_728.xml
# No citphrases found in: 09_73.xml
# No citphrases found in: 09_730.xml
# Processed and saved as JSON: 09_731.xml
# Processed and saved as JSON: 09_733.xml
# No citphrases found in: 09_734.xml
# Processed and saved as JSON: 09_737.xml
# Processed and saved as JSON: 09_738.xml
# Processed and saved as JSON: 09_740.xml
# No citphrases found in: 09_741.xml
# Processed and saved as JSON: 09_742.xml
# Processed and saved as JSON: 09_743.xml
# Processed and saved as JSON: 09_744.xml
# Processed and saved as JSON: 09_747.xml
# Processed and saved as JSON: 09_749.xml
# Processed and saved as JSON: 09_750.xml
# Processed and saved as JSON: 09_753.xml
# Processed and saved as JSON: 09_754.xml
# Processed and saved as JSON: 09_755.xml
# Processed and saved as JSON: 09_756.xml
# Processed and saved as JSON: 09_757.xml
# Processed and saved as JSON: 09_758.xml
# Processed and saved as JSON: 09_759.xml
# Processed and saved as JSON: 09_760.xml
# Processed and saved as JSON: 09_761.xml
# Processed and saved as JSON: 09_763.xml
# Processed and saved as JSON: 09_767.xml
# Processed and saved as JSON: 09_770.xml
# Processed and saved as JSON: 09_771.xml
# Processed and saved as JSON: 09_772.xml
# Processed and saved as JSON: 09_773.xml
# Processed and saved as JSON: 09_774.xml
# Processed and saved as JSON: 09_776.xml
# Processed and saved as JSON: 09_778.xml
# Processed and saved as JSON: 09_779.xml
# Processed and saved as JSON: 09_780.xml
# Processed and saved as JSON: 09_781.xml
# Processed and saved as JSON: 09_783.xml
# Processed and saved as JSON: 09_784.xml
# Processed and saved as JSON: 09_786.xml
# Processed and saved as JSON: 09_787.xml
# Processed and saved as JSON: 09_789.xml
# Processed and saved as JSON: 09_79.xml
# Processed and saved as JSON: 09_794.xml
# Processed and saved as JSON: 09_795.xml
# Processed and saved as JSON: 09_797.xml
# Processed and saved as JSON: 09_798.xml
# Processed and saved as JSON: 09_799.xml
# Processed and saved as JSON: 09_8.xml
# Processed and saved as JSON: 09_800.xml
# Processed and saved as JSON: 09_801.xml
# Processed and saved as JSON: 09_803.xml
# Processed and saved as JSON: 09_809.xml
# No citphrases found in: 09_811.xml
# Processed and saved as JSON: 09_813.xml
# Processed and saved as JSON: 09_814.xml
# Processed and saved as JSON: 09_818.xml
# Processed and saved as JSON: 09_819.xml
# Processed and saved as JSON: 09_82.xml
# Processed and saved as JSON: 09_827.xml
# Processed and saved as JSON: 09_829.xml
# Processed and saved as JSON: 09_83.xml
# Processed and saved as JSON: 09_830.xml
# Processed and saved as JSON: 09_832.xml
# Processed and saved as JSON: 09_833.xml
# Processed and saved as JSON: 09_834.xml
# Processed and saved as JSON: 09_837.xml
# Processed and saved as JSON: 09_838.xml
# Processed and saved as JSON: 09_839.xml
# No citphrases found in: 09_84.xml
# Processed and saved as JSON: 09_841.xml
# Processed and saved as JSON: 09_842.xml
# Processed and saved as JSON: 09_843.xml
# Processed and saved as JSON: 09_844.xml
# Processed and saved as JSON: 09_845.xml
# Processed and saved as JSON: 09_846.xml
# Processed and saved as JSON: 09_847.xml
# Processed and saved as JSON: 09_849.xml
# Processed and saved as JSON: 09_85.xml
# Processed and saved as JSON: 09_851.xml
# Processed and saved as JSON: 09_852.xml
# No citphrases found in: 09_853.xml
# Processed and saved as JSON: 09_856.xml
# Processed and saved as JSON: 09_864.xml
# Processed and saved as JSON: 09_865.xml
# Processed and saved as JSON: 09_868.xml
# Processed and saved as JSON: 09_87.xml
# Processed and saved as JSON: 09_872.xml
# Processed and saved as JSON: 09_873.xml
# Processed and saved as JSON: 09_874.xml
# Processed and saved as JSON: 09_875.xml
# Processed and saved as JSON: 09_877.xml
# Processed and saved as JSON: 09_878.xml
# Processed and saved as JSON: 09_88.xml
# Processed and saved as JSON: 09_880.xml
# Processed and saved as JSON: 09_881.xml
# Processed and saved as JSON: 09_882.xml
# Processed and saved as JSON: 09_883.xml
# Processed and saved as JSON: 09_885.xml
# Processed and saved as JSON: 09_886.xml
# Processed and saved as JSON: 09_888.xml
# Processed and saved as JSON: 09_89.xml
# Processed and saved as JSON: 09_890.xml
# Processed and saved as JSON: 09_891.xml
# Processed and saved as JSON: 09_892.xml
# Processed and saved as JSON: 09_894.xml
# Processed and saved as JSON: 09_897.xml
# Processed and saved as JSON: 09_90.xml
# Processed and saved as JSON: 09_901.xml
# Processed and saved as JSON: 09_902.xml
# Processed and saved as JSON: 09_903.xml
# Processed and saved as JSON: 09_906.xml
# Processed and saved as JSON: 09_907.xml
# Processed and saved as JSON: 09_908.xml
# Processed and saved as JSON: 09_912.xml
# Processed and saved as JSON: 09_915.xml
# No citphrases found in: 09_92.xml
# Processed and saved as JSON: 09_920.xml
# Processed and saved as JSON: 09_921.xml
# Processed and saved as JSON: 09_922.xml
# Processed and saved as JSON: 09_924.xml
# Processed and saved as JSON: 09_929.xml
# Processed and saved as JSON: 09_93.xml
# Processed and saved as JSON: 09_930.xml
# Processed and saved as JSON: 09_931.xml
# Processed and saved as JSON: 09_932.xml
# Processed and saved as JSON: 09_933.xml
# Processed and saved as JSON: 09_935.xml
# Processed and saved as JSON: 09_936.xml
# Processed and saved as JSON: 09_940.xml
# Processed and saved as JSON: 09_941.xml
# Processed and saved as JSON: 09_943.xml
# Processed and saved as JSON: 09_945.xml
# Processed and saved as JSON: 09_949.xml
# Processed and saved as JSON: 09_95.xml
# Processed and saved as JSON: 09_952.xml
# Processed and saved as JSON: 09_953.xml
# Processed and saved as JSON: 09_954.xml
# Processed and saved as JSON: 09_955.xml
# Processed and saved as JSON: 09_956.xml
# No citphrases found in: 09_957.xml
# Processed and saved as JSON: 09_959.xml
# Processed and saved as JSON: 09_96.xml
# Processed and saved as JSON: 09_960.xml
# Processed and saved as JSON: 09_962.xml
# Processed and saved as JSON: 09_963.xml
# Processed and saved as JSON: 09_965.xml
# Processed and saved as JSON: 09_966.xml
# Processed and saved as JSON: 09_967.xml
# Processed and saved as JSON: 09_97.xml
# Processed and saved as JSON: 09_970.xml
# Processed and saved as JSON: 09_971.xml
# Processed and saved as JSON: 09_972.xml
# Processed and saved as JSON: 09_976.xml
# Processed and saved as JSON: 09_977.xml
# Processed and saved as JSON: 09_978.xml
# Processed and saved as JSON: 09_979.xml
# Processed and saved as JSON: 09_980.xml
# Processed and saved as JSON: 09_981.xml
# Processed and saved as JSON: 09_983.xml
# Processed and saved as JSON: 09_984.xml
# Processed and saved as JSON: 09_985.xml
# Processed and saved as JSON: 09_99.xml
# Processed and saved as JSON: 09_991.xml
# Processed and saved as JSON: 09_992.xml
# Processed and saved as JSON: 09_996.xml
#
# Processing complete. Summary:
# Total files processed: 3890
# Successfully cleaned files: 3538
# Files with errors: 352
